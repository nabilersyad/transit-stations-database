# %% [markdown]
# # Visualizing data in the transit_database SQLite database
#
# We know from the work in the other notebooks in this file that this database contains 3 tables with various station details
# This notebook will demonstrate ways to manipulate the tables and also a simple visualization of the station's location in a Folium map.
#
# Much of the work here has been created with chatGPT plus

# %%
import pandas as pd
import sqlite3
import geopandas as gpd
from shapely.geometry import Point
import folium

# %% [markdown]
# ### Query for data
#
# We will merge station table with the other two entrances table. Note that doing this means there will be several rows where the station coordinate will be duplicated.

# %%
# Create a connection to the SQLite database
conn = sqlite3.connect('transit_database.db')

# SQL query
query = """
SELECT stations.*, 
       station_entrances."entrance_id", 
       entrances."longitude" as entrance_longitude, 
       entrances."latitude" as entrance_latitude
FROM stations
LEFT JOIN station_entrances
ON stations."station_id" = station_entrances."station_id"
LEFT JOIN entrances
ON station_entrances."entrance_id" = entrances."entrance_id"
WHERE stations.region='Klang Valley'
"""

# Load the data into a pandas DataFrame
klang_valley_df = pd.read_sql_query(query, conn)

# Don't forget to close the connection
conn.close()

# %% [markdown]
# ### Create Geopandas and geometry objects
#
# This part isn't necessary, but I believe that it is good practice to use geopandas when working with geographic data.
# This part will convert a normal pandas dataframe to a geopandas dataframe using the station's coordinates as the main geometry.

# %%
# Create a new column in your DataFrame for the geographic data
klang_valley_df['geometry'] = [Point(xy) for xy in zip(klang_valley_df.longitude, klang_valley_df.latitude)]

# Convert the DataFrame to a GeoDataFrame
klang_valley_gdf = gpd.GeoDataFrame(klang_valley_df, geometry='geometry')

# Set the coordinate reference system (CRS) to EPSG:4326 (WGS84)
klang_valley_gdf.crs = "EPSG:4326"

# %% [markdown]
# #### Visualizing stations in the form of markers using lat,long coordinates columns (geopandas not necessary)

# %%
# Create a new DataFrame where each latitude and longitude pair is unique
unique_stations = klang_valley_gdf.drop_duplicates(subset=['latitude', 'longitude'])

# Create a map centered around the average latitude and longitude of the stations
map = folium.Map(location=[unique_stations['latitude'].mean(), unique_stations['longitude'].mean()], zoom_start=13)

# Add a marker for each station
for _, station in unique_stations.iterrows():
    folium.Marker(location=[station['latitude'], station['longitude']], 
                  popup=f"{station['name']} ({station['station_id']})").add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d58ac3516a70775fe0885e1fc76889a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d58ac3516a70775fe0885e1fc76889a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d58ac3516a70775fe0885e1fc76889a4 = L.map(
#                 &quot;map_d58ac3516a70775fe0885e1fc76889a4&quot;,
#                 {
#                     center: [3.107310316518041, 101.67108848865979],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1d7028f196efee90d44e63a2a534965 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d58ac3516a70775fe0885e1fc76889a4);
#
#
#             var marker_0d379f70eab85908b037bcd4dce16d50 = L.marker(
#                 [3.134603, 101.686567],
#                 {}
#             ).addTo(map_d58ac3516a70775fe0885e1fc76889a4);
#
#
#         var popup_6345c085ae5e29a614aaff449e2fdac5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f1c65e1fdf436298904e8ccea6963a4 = $(`&lt;div id=&quot;html_0f1c65e1fdf436298904e8ccea6963a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KL Sentral (KA01)&lt;/div&gt;`)[0];
#                 popup_6345c085ae5e29a614aaff449e2fdac5.setContent(html_0f1c65e1fdf436298904e8ccea6963a4);
#
#
#
#         marker_0d379f70eab85908b037bcd4dce16d50.bindPopup(popup_6345c085ae5e29a614aaff449e2fdac5)
#         ;
#
#
#
#
#             var marker_0dc12c88e136ef6f9cd19c57ca5af267 = L.marker(
#                 [3.1395126, 101.6937889],
#                 {}
#             ).addTo(map_d58ac3516a70775fe0885e1fc76889a4);
#
#
#         var popup_67381db495314eef8e8a81fcb0c8b9e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_248cf63432cee6f0e9a50d5e706de9c9 = $(`&lt;div id=&quot;html_248cf63432cee6f0e9a50d5e706de9c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kuala Lumpur (KA02)&lt;/div&gt;`)[0];
#                 popup_67381db495314eef8e8a81fcb0c8b9e8.setContent(html_248cf63432cee6f0e9a50d5e706de9c9);
#
#
#
#         marker_0dc12c88e136ef6f9cd19c57ca5af267.bindPopup(popup_67381db495314eef8e8a81fcb0c8b9e8)
#         ;
#
#
#
#
#             var marker_8b32e05ccfbb454e268497f3adcbdea2 = L.marker(
#                 [3.1545422, 101.6930105],
#                 {}
#             ).addTo(map_d58ac3516a70775fe0885e1fc76889a4);
#
#
#         var popup_ec27c8663246cc6bedebf53b3b075bc3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6772e304f2e8cca29853b4862dc97d9 = $(`&lt;div id=&quot;html_f6772e304f2e8cca29853b4862dc97d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bank Negara (KA03)&lt;/div&gt;`)[0];
#                 popup_ec27c8663246cc6bedebf53b3b075bc3.setContent(html_f6772e304f2e8cca29853b4862dc97d9);
#
#
#
#         marker_8b32e05ccfbb454e268497f3adcbdea2.bindPopup(popup_ec27c8663246cc6bedebf53b3b075bc3)
#         ;
#
#
#
#
#             var marker_53528e25c5c05abcaa91316c6f2ae71d = L.marker(
#                 [3.165005, 101.691234],
#                 {}
#             ).addTo(map_d58ac3516a70775fe0885e1fc76889a4);
#
#
#         var popup_13c17e91a626df9090443bf08cd23dae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8bfe28b4e13366d35b14f767cc7f057 = $(`&lt;div id=&quot;html_d8bfe28b4e13366d35b14f767cc7f057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Putra (KA04)&lt;/div&gt;`)[0];
#                 popup_13c17e91a626df9090443bf08cd23dae.setContent(html_d8bfe28b4e13366d35b14f767cc7f057);
#
#
#
#         marker_53528e25c5c05abcaa91316c6f2ae71d.bindPopup(popup_13c17e91a626df9090443bf08cd23dae)
#         ;
#
#
#
#
#             var marker_b2d6740c4e23977f3c34b9da0a670f78 = L.marker(
#                 [3.1185282, 101.6789854],
#                 {}
#             ).addTo(map_d58ac3516a70775fe0885e1fc76889a4);
#
#
#         var popup_657825f1338289e58737932e1a8039c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1426553dafa1ead40c2ccc33a6dc8f5 = $(`&lt;div id=&quot;html_b1426553dafa1ead40c2ccc33a6dc8f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mid Valley (KB01)&lt;/div&gt;`)[0];
#                 popup_657825f1338289e58737932e1a8039c2.setContent(html_b1426553dafa1ead40c2ccc33a6dc8f5);
#
#
#
#         marker_b2d6740c4e23977f3c34b9da0a670f78.bindPopup(popup_657825f1338289e58737932e1a8039c2)
#         ;
#
#
#
#
#             var marker_2dffa33fd6e52314712aa33d894d9091 = L.marker(

# %% [markdown]
# #### Visualizing stations in the form of markers using geometry object column (must use geopandas)

# %%
# Create a new GeoDataFrame where each geometry is unique
unique_stations_gdf = klang_valley_gdf.drop_duplicates(subset=['geometry'])

# Create a map centered around the average latitude and longitude of the stations
klang_valley_map = folium.Map(location=[unique_stations_gdf['geometry'].y.mean(), unique_stations_gdf['geometry'].x.mean()], zoom_start=10)

# Add a marker for each station
for _, row in unique_stations_gdf.iterrows():
    folium.Marker(
        location=[row['geometry'].y, row['geometry'].x],  # Extract latitude and longitude from Point object
        popup=f"Station ID: {row['station_id']}<br>Name: {row['name']}<br>Provider: {row['service_provider_name']}"
    ).add_to(klang_valley_map)

# Display the map
klang_valley_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e0eb40203b765cc378c6362f5445ae6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e0eb40203b765cc378c6362f5445ae6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e0eb40203b765cc378c6362f5445ae6 = L.map(
#                 &quot;map_5e0eb40203b765cc378c6362f5445ae6&quot;,
#                 {
#                     center: [3.0966632591872343, 101.65890534765956],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8114b52652fd8f3e3b169d3ab4776c7c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e0eb40203b765cc378c6362f5445ae6);
#
#
#             var marker_70938bbd7f04d924cccc5ff985bdc9ca = L.marker(
#                 [3.134603, 101.686567],
#                 {}
#             ).addTo(map_5e0eb40203b765cc378c6362f5445ae6);
#
#
#         var popup_35110e005ce062885164f0d45750ac92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61f8471e571951bfacc9da89a166bfb7 = $(`&lt;div id=&quot;html_61f8471e571951bfacc9da89a166bfb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: KA01&lt;br&gt;Name: KL Sentral&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_35110e005ce062885164f0d45750ac92.setContent(html_61f8471e571951bfacc9da89a166bfb7);
#
#
#
#         marker_70938bbd7f04d924cccc5ff985bdc9ca.bindPopup(popup_35110e005ce062885164f0d45750ac92)
#         ;
#
#
#
#
#             var marker_4f40b3bf1930cf8b73be6baa1d25d631 = L.marker(
#                 [3.1395126, 101.6937889],
#                 {}
#             ).addTo(map_5e0eb40203b765cc378c6362f5445ae6);
#
#
#         var popup_49c281daa613cf4746a226aca19a028c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2550d7d232b42caaabe43662b54ccfe8 = $(`&lt;div id=&quot;html_2550d7d232b42caaabe43662b54ccfe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: KA02&lt;br&gt;Name: Kuala Lumpur&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_49c281daa613cf4746a226aca19a028c.setContent(html_2550d7d232b42caaabe43662b54ccfe8);
#
#
#
#         marker_4f40b3bf1930cf8b73be6baa1d25d631.bindPopup(popup_49c281daa613cf4746a226aca19a028c)
#         ;
#
#
#
#
#             var marker_60c2d341994859bf14533cbce08bc5da = L.marker(
#                 [3.1545422, 101.6930105],
#                 {}
#             ).addTo(map_5e0eb40203b765cc378c6362f5445ae6);
#
#
#         var popup_e079c018bdb69015e4efdf92f6b34b4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb56bb35fece3d55e13acdd1c57de3fb = $(`&lt;div id=&quot;html_eb56bb35fece3d55e13acdd1c57de3fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: KA03&lt;br&gt;Name: Bank Negara&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_e079c018bdb69015e4efdf92f6b34b4f.setContent(html_eb56bb35fece3d55e13acdd1c57de3fb);
#
#
#
#         marker_60c2d341994859bf14533cbce08bc5da.bindPopup(popup_e079c018bdb69015e4efdf92f6b34b4f)
#         ;
#
#
#
#
#             var marker_1c1728eaa838b966f495edc637347473 = L.marker(
#                 [3.165005, 101.691234],
#                 {}
#             ).addTo(map_5e0eb40203b765cc378c6362f5445ae6);
#
#
#         var popup_efa7f737f2cd0be9164f9e729645b232 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63d51dddb199a8959973d6d9827dcc9c = $(`&lt;div id=&quot;html_63d51dddb199a8959973d6d9827dcc9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: KA04&lt;br&gt;Name: Putra&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_efa7f737f2cd0be9164f9e729645b232.setContent(html_63d51dddb199a8959973d6d9827dcc9c);
#
#
#
#         marker_1c1728eaa838b966f495edc637347473.bindPopup(popup_efa7f737f2cd0be9164f9e729645b232)
#         ;
#
#
#
#
#             var marker_73414f758dca2a4a271baad5ff7fee15 = L.marker(
#                 [3.1185282, 101.6789854],
#                 {}
#             ).addTo(map_5e0eb40203b765cc378c6362f5445ae6);
#
#
#         var popup_e9fcaa0c4c217d7f76a11ed63854b66f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b854230e4905ba848ac4e6477212d400 = $(`&lt;div id=&quot;html_b854230e4905ba848ac4e6477212d400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: KB01&lt;br&gt;Name: Mid Valley&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
