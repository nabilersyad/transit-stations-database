# %% [markdown]
# # Visualizing data in the transit_database SQLite database
#
# We know from the work in the other notebooks in this file that this database contains 3 tables with various station details
# This notebook will demonstrate ways to manipulate the tables and also a simple visualization of the station's location in a Folium map.
#
# Much of the work here has been created with chatGPT plus

# %%
import pandas as pd
import sqlite3
import geopandas as gpd
from shapely.geometry import Point
import folium

# %% [markdown]
# ### Query for data
#
# We will merge station table with the other two entrances table. Note that doing this means there will be several rows where the station coordinate will be duplicated.

# %%
# Create a connection to the SQLite database
conn = sqlite3.connect('../transit_database.db')

# SQL query
query = """
SELECT stations.*, 
       station_entrances."entrance_id", 
       entrances."longitude" as entrance_longitude, 
       entrances."latitude" as entrance_latitude
FROM stations
LEFT JOIN station_entrances
ON stations."station_code" = station_entrances."station_code"
LEFT JOIN entrances
ON station_entrances."entrance_id" = entrances."entrance_id"
WHERE stations.region='Klang Valley'
"""

# Load the data into a pandas DataFrame
klang_valley_df = pd.read_sql_query(query, conn)

# Don't forget to close the connection
conn.close()

# %% [markdown]
# ### Create Geopandas and geometry objects
#
# This part isn't necessary, but I believe that it is good practice to use geopandas when working with geographic data.
# This part will convert a normal pandas dataframe to a geopandas dataframe using the station's coordinates as the main geometry.

# %%
# Create a new column in your DataFrame for the geographic data
klang_valley_df['geometry'] = [Point(xy) for xy in zip(klang_valley_df.longitude, klang_valley_df.latitude)]

# Convert the DataFrame to a GeoDataFrame
klang_valley_gdf = gpd.GeoDataFrame(klang_valley_df, geometry='geometry')

# Set the coordinate reference system (CRS) to EPSG:4326 (WGS84)
klang_valley_gdf.crs = "EPSG:4326"

# %% [markdown]
# #### Visualizing stations in the form of markers using lat,long coordinates columns (geopandas not necessary)

# %%
# Create a new DataFrame where each latitude and longitude pair is unique
unique_stations = klang_valley_gdf.drop_duplicates(subset=['latitude', 'longitude'])

# Create a map centered around the average latitude and longitude of the stations
map = folium.Map(location=[unique_stations['latitude'].mean(), unique_stations['longitude'].mean()], zoom_start=13)

# Add a marker for each station
for _, station in unique_stations.iterrows():
    folium.Marker(location=[station['latitude'], station['longitude']], 
                  popup=f"{station['name']} ({station['station_id']})").add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79414605ae21ac6fef541a2b4352fd4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79414605ae21ac6fef541a2b4352fd4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79414605ae21ac6fef541a2b4352fd4d = L.map(
#                 &quot;map_79414605ae21ac6fef541a2b4352fd4d&quot;,
#                 {
#                     center: [3.0966632591872343, 101.65890534765956],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3f96143894d05b939a953eddcc6b620 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_79414605ae21ac6fef541a2b4352fd4d);
#
#
#             var marker_e731bc8fa159dd2a4d59feb6300740ff = L.marker(
#                 [3.134603, 101.686567],
#                 {}
#             ).addTo(map_79414605ae21ac6fef541a2b4352fd4d);
#
#
#         var popup_02cffcaa2c8930a8197b6648065d6c07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a924b14de8e3a0d695f03559d5faba8 = $(`&lt;div id=&quot;html_7a924b14de8e3a0d695f03559d5faba8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KL Sentral (0)&lt;/div&gt;`)[0];
#                 popup_02cffcaa2c8930a8197b6648065d6c07.setContent(html_7a924b14de8e3a0d695f03559d5faba8);
#
#
#
#         marker_e731bc8fa159dd2a4d59feb6300740ff.bindPopup(popup_02cffcaa2c8930a8197b6648065d6c07)
#         ;
#
#
#
#
#             var marker_459e2a5760be94066def2c269da4d462 = L.marker(
#                 [3.1395126, 101.6937889],
#                 {}
#             ).addTo(map_79414605ae21ac6fef541a2b4352fd4d);
#
#
#         var popup_03ea3a10e429399b37cf50db39338c0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f805a3d39ac2c16f0e2fff4003d1e249 = $(`&lt;div id=&quot;html_f805a3d39ac2c16f0e2fff4003d1e249&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kuala Lumpur (1)&lt;/div&gt;`)[0];
#                 popup_03ea3a10e429399b37cf50db39338c0d.setContent(html_f805a3d39ac2c16f0e2fff4003d1e249);
#
#
#
#         marker_459e2a5760be94066def2c269da4d462.bindPopup(popup_03ea3a10e429399b37cf50db39338c0d)
#         ;
#
#
#
#
#             var marker_2c6705e1b3708c4cbb748508119cd9d9 = L.marker(
#                 [3.1545422, 101.6930105],
#                 {}
#             ).addTo(map_79414605ae21ac6fef541a2b4352fd4d);
#
#
#         var popup_6ad791cba66c71f45877db1fc3f7e945 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf011b4d5da94387757ff767e8ae57ec = $(`&lt;div id=&quot;html_bf011b4d5da94387757ff767e8ae57ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bank Negara (2)&lt;/div&gt;`)[0];
#                 popup_6ad791cba66c71f45877db1fc3f7e945.setContent(html_bf011b4d5da94387757ff767e8ae57ec);
#
#
#
#         marker_2c6705e1b3708c4cbb748508119cd9d9.bindPopup(popup_6ad791cba66c71f45877db1fc3f7e945)
#         ;
#
#
#
#
#             var marker_fdd9f7c17df4e2513c7f5a38feda3081 = L.marker(
#                 [3.165005, 101.691234],
#                 {}
#             ).addTo(map_79414605ae21ac6fef541a2b4352fd4d);
#
#
#         var popup_d0999142bba835489e05677d40af9473 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b7e0fc2f8c662fcf7f2770b11a66ce7 = $(`&lt;div id=&quot;html_2b7e0fc2f8c662fcf7f2770b11a66ce7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Putra (3)&lt;/div&gt;`)[0];
#                 popup_d0999142bba835489e05677d40af9473.setContent(html_2b7e0fc2f8c662fcf7f2770b11a66ce7);
#
#
#
#         marker_fdd9f7c17df4e2513c7f5a38feda3081.bindPopup(popup_d0999142bba835489e05677d40af9473)
#         ;
#
#
#
#
#             var marker_656b6b2d6dc974481b6f7756e10b53ca = L.marker(
#                 [3.1185282, 101.6789854],
#                 {}
#             ).addTo(map_79414605ae21ac6fef541a2b4352fd4d);
#
#
#         var popup_378e0a0fa2ab2944899c69e6dd6ac667 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48ec399690d36fc2d4de3a6bb7c60ffc = $(`&lt;div id=&quot;html_48ec399690d36fc2d4de3a6bb7c60ffc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mid Valley (4)&lt;/div&gt;`)[0];
#                 popup_378e0a0fa2ab2944899c69e6dd6ac667.setContent(html_48ec399690d36fc2d4de3a6bb7c60ffc);
#
#
#
#         marker_656b6b2d6dc974481b6f7756e10b53ca.bindPopup(popup_378e0a0fa2ab2944899c69e6dd6ac667)
#         ;
#
#
#
#
#             var marker_3a1e4284b35482bc53ec4b2e4fe91111 = L.marker(
#                 [3.1136966, 1

# %% [markdown]
# #### Visualizing stations in the form of markers using geometry object column (must use geopandas)

# %%
# Create a new GeoDataFrame where each geometry is unique
unique_stations_gdf = klang_valley_gdf.drop_duplicates(subset=['geometry'])

# Create a map centered around the average latitude and longitude of the stations
klang_valley_map = folium.Map(location=[unique_stations_gdf['geometry'].y.mean(), unique_stations_gdf['geometry'].x.mean()], zoom_start=10)

# Add a marker for each station
for _, row in unique_stations_gdf.iterrows():
    folium.Marker(
        location=[row['geometry'].y, row['geometry'].x],  # Extract latitude and longitude from Point object
        popup=f"Station ID: {row['station_id']}<br>Name: {row['name']}<br>Provider: {row['service_provider_name']}"
    ).add_to(klang_valley_map)

# Display the map
klang_valley_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a35cae0b0b6ba95fa152174487d786f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a35cae0b0b6ba95fa152174487d786f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a35cae0b0b6ba95fa152174487d786f = L.map(
#                 &quot;map_1a35cae0b0b6ba95fa152174487d786f&quot;,
#                 {
#                     center: [3.0966632591872343, 101.65890534765956],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b13ceba34febad01dd3149da75b35f16 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a35cae0b0b6ba95fa152174487d786f);
#
#
#             var marker_38a5a54149de56b90cb957830fae9849 = L.marker(
#                 [3.134603, 101.686567],
#                 {}
#             ).addTo(map_1a35cae0b0b6ba95fa152174487d786f);
#
#
#         var popup_16c8878576b0e90f52a13c58f0af4daf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54c49547885ad404da6a43bb1c4daa90 = $(`&lt;div id=&quot;html_54c49547885ad404da6a43bb1c4daa90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 0&lt;br&gt;Name: KL Sentral&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_16c8878576b0e90f52a13c58f0af4daf.setContent(html_54c49547885ad404da6a43bb1c4daa90);
#
#
#
#         marker_38a5a54149de56b90cb957830fae9849.bindPopup(popup_16c8878576b0e90f52a13c58f0af4daf)
#         ;
#
#
#
#
#             var marker_28d4763d57cc8bc861e766d3ba1b9eb3 = L.marker(
#                 [3.1395126, 101.6937889],
#                 {}
#             ).addTo(map_1a35cae0b0b6ba95fa152174487d786f);
#
#
#         var popup_8e4b32baa654f1e70051848d8d3b92ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34e2145accbfdc5d618a217efbe9f437 = $(`&lt;div id=&quot;html_34e2145accbfdc5d618a217efbe9f437&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 1&lt;br&gt;Name: Kuala Lumpur&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_8e4b32baa654f1e70051848d8d3b92ba.setContent(html_34e2145accbfdc5d618a217efbe9f437);
#
#
#
#         marker_28d4763d57cc8bc861e766d3ba1b9eb3.bindPopup(popup_8e4b32baa654f1e70051848d8d3b92ba)
#         ;
#
#
#
#
#             var marker_72f4e32069b30ee320add0b3112f34d4 = L.marker(
#                 [3.1545422, 101.6930105],
#                 {}
#             ).addTo(map_1a35cae0b0b6ba95fa152174487d786f);
#
#
#         var popup_9f959467c08b837dce45ce5e31c94c75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aba7b2ac5478cd316ffdca53445244eb = $(`&lt;div id=&quot;html_aba7b2ac5478cd316ffdca53445244eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 2&lt;br&gt;Name: Bank Negara&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_9f959467c08b837dce45ce5e31c94c75.setContent(html_aba7b2ac5478cd316ffdca53445244eb);
#
#
#
#         marker_72f4e32069b30ee320add0b3112f34d4.bindPopup(popup_9f959467c08b837dce45ce5e31c94c75)
#         ;
#
#
#
#
#             var marker_cc04a566f19b56a778a58e7c2eec810c = L.marker(
#                 [3.165005, 101.691234],
#                 {}
#             ).addTo(map_1a35cae0b0b6ba95fa152174487d786f);
#
#
#         var popup_4014e65fa41abd70b1554a06e4c696af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68ba220862f75c4decfbd0f5b829e1ac = $(`&lt;div id=&quot;html_68ba220862f75c4decfbd0f5b829e1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 3&lt;br&gt;Name: Putra&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_4014e65fa41abd70b1554a06e4c696af.setContent(html_68ba220862f75c4decfbd0f5b829e1ac);
#
#
#
#         marker_cc04a566f19b56a778a58e7c2eec810c.bindPopup(popup_4014e65fa41abd70b1554a06e4c696af)
#         ;
#
#
#
#
#             var marker_2ba73012d0dc79f090b70a994ef0808d = L.marker(
#                 [3.1185282, 101.6789854],
#                 {}
#             ).addTo(map_1a35cae0b0b6ba95fa152174487d786f);
#
#
#         var popup_3054ab1bc05b40c90f4bfc2030d4e167 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff3f6f14a028ba3164759e12f35db0c2 = $(`&lt;div id=&quot;html_ff3f6f14a028ba3164759e12f35db0c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 4&lt;br&gt;Name: Mid Valley&lt;br&gt;Provider: Keretapi Tanah Melayu&lt;/div&gt;`)[0];
#                 popup_30

# %% [markdown]
# #### Visualizing all available station entrances

# %%
# Create a new DataFrame where each entrances latitude and longitude pair is available
valid_entrances = klang_valley_gdf.dropna(subset=['entrance_latitude', 'entrance_longitude'])

# Create a map centered around the average latitude and longitude of the stations
map = folium.Map(location=[valid_entrances['entrance_latitude'].mean(), valid_entrances['entrance_longitude'].mean()], zoom_start=13)

# Add a marker for each station
for _, entrance in valid_entrances.iterrows():
    folium.Marker(location=[entrance['entrance_latitude'], entrance['entrance_longitude']], 
                  popup=f"{entrance['name']} ({entrance['station_id']})",
                  icon=folium.Icon(color="red", icon="")
                  ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e51419f6e55093fd9c6a47a0e06cdbe4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e51419f6e55093fd9c6a47a0e06cdbe4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e51419f6e55093fd9c6a47a0e06cdbe4 = L.map(
#                 &quot;map_e51419f6e55093fd9c6a47a0e06cdbe4&quot;,
#                 {
#                     center: [3.1272176287625415, 101.68926708896322],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b670c8036ba1e98e14d9ca0ba274afc0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e51419f6e55093fd9c6a47a0e06cdbe4);
#
#
#             var marker_208be4e997d50d2f1b52553ea4d78a71 = L.marker(
#                 [3.1650272, 101.6911614],
#                 {}
#             ).addTo(map_e51419f6e55093fd9c6a47a0e06cdbe4);
#
#
#             var icon_f082f1f2f92f9fccc34fa1bdcf853983 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_208be4e997d50d2f1b52553ea4d78a71.setIcon(icon_f082f1f2f92f9fccc34fa1bdcf853983);
#
#
#         var popup_686bf8f9f6ea2d8ee8901cee3ccee4cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3bdf151b2fa05001bd9bec222a45f12 = $(`&lt;div id=&quot;html_f3bdf151b2fa05001bd9bec222a45f12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Putra (3)&lt;/div&gt;`)[0];
#                 popup_686bf8f9f6ea2d8ee8901cee3ccee4cf.setContent(html_f3bdf151b2fa05001bd9bec222a45f12);
#
#
#
#         marker_208be4e997d50d2f1b52553ea4d78a71.bindPopup(popup_686bf8f9f6ea2d8ee8901cee3ccee4cf)
#         ;
#
#
#
#
#             var marker_7ae7f6845d4e97a2583a707624073cb3 = L.marker(
#                 [2.9838212, 101.79089],
#                 {}
#             ).addTo(map_e51419f6e55093fd9c6a47a0e06cdbe4);
#
#
#             var icon_7ed56c9d86471e32d349004b289e7cb7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ae7f6845d4e97a2583a707624073cb3.setIcon(icon_7ed56c9d86471e32d349004b289e7cb7);
#
#
#         var popup_8ff14923feb41bc512d8a0845112ae27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4ba33a5a34966fe2e9b5c9c339bb17b = $(`&lt;div id=&quot;html_f4ba33a5a34966fe2e9b5c9c339bb17b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kajang (9)&lt;/div&gt;`)[0];
#                 popup_8ff14923feb41bc512d8a0845112ae27.setContent(html_f4ba33a5a34966fe2e9b5c9c339bb17b);
#
#
#
#         marker_7ae7f6845d4e97a2583a707624073cb3.bindPopup(popup_8ff14923feb41bc512d8a0845112ae27)
#         ;
#
#
#
#
#             var marker_09fe9edb5520d276492c43175ec488c9 = L.marker(
#                 [2.9829814, 101.7900849],
#                 {}
#             ).addTo(map_e51419f6e55093fd9c6a47a0e06cdbe4);
#
#
#             var icon_ea96f6bef84499aad998f3852930d27d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_09fe9edb5520d276492c43175ec488c9.setIcon(icon_ea96f6bef84499aad998f3852930d27d);
#
#
#         var popup_3a7bf2ee1fac2f7e46bb15c5a43f0f52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_968963af90460c1b027d56301d22958c = $(`&lt;div id=&quot;html_968963af90460c1b027d56301d22958c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kajang (9)&lt;/div&gt;`)[0];
#                 popup_3a7bf2ee1fac2f7e46bb15c5a43f0f52.setContent(html_968963af90460c1b027d56301d22958c);
#
#
#
#         marker_09fe9edb5520d276492c43175ec488c9.bindPopup(popup_3a7bf2ee1fac2f7e46bb15c5a43f0f52)
#         ;
#
#
#
#
#             var marker_cc64673754adcd0a16e520e51fb43eb4 = L.marker(
#                 [2.5928462, 102.0943571],
#                 {}
#             ).addTo(map_e51419f6e55093fd9c6a47a0e06cdbe4);
#
#
#             var icon_1bf599b1abe283163c262616caaafe2a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;icon

# %% [markdown]
# ### Supabase Database
#
# As of August 2023, we have started migration to Supabase. The database has already been created through manually uploading of CSV files.
#
# Here we will try and connect to the Supabase instance and visualize the same data as above.

# %%
import os
import pandas as pd
from supabase import create_client, Client

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)
# Initialize the Supabase client

# %%
#Query stations table
response = supabase.table('stations').select("*").eq('region', 'Klang Valley').execute()
data,_ = response
stations_data_supa = pd.DataFrame(data[1])
stations_data_supa = stations_data_supa.set_index('station_id')

#Query station entrances table
response = supabase.table('station_entrances').select("*").execute()
data,_ = response
station_entrances_data_supa = pd.DataFrame(data[1])
station_entrances_data_supa.index.name = 'relationship_id'
station_entrances_data_supa.drop({'relationship_id'},inplace=True,axis=1)
station_entrances_data_supa


#Query entrances table
response = supabase.table('entrances').select("*").execute()
data,_ = response
entrances_data_supa = pd.DataFrame(data[1])
entrances_data_supa = entrances_data_supa.set_index('entrance_id')
entrances_data_supa.rename(columns={
    'longitude': 'entrance_longitude',
    'latitude': 'entrance_latitude'
}, inplace=True)
entrances_data_supa
# Out:
#              entrance_longitude  entrance_latitude entrance_destination  \
# entrance_id
# 3308608988           101.712717           3.158762                 None
# 3308608989           101.712507           3.158809                 None
# 4092013971           101.614130           3.022231                 None
# 4400847336           101.698939           3.139210                 None
# 4952299503           101.732720           3.104671                 None
# ...                         ...                ...                  ...
# 11292475708          101.687127           3.134788                 None
# 11292475709          101.685544           3.133838                 None
# 11292475710          101.686072           3.134891                 None
# 11899741782          101.710384           3.145855                 None
# 11925140813          101.686758           3.133750                 None
#
#             entrance_name
# entrance_id
# 3308608988           None
# 3308608989           None
# 4092013971           None
# 4400847336              A
# 4952299503              B
# ...                   ...
# 11292475708          None
# 11292475709          None
# 11292475710          None
# 11899741782            B1
# 11925140813          None
#
# [275 rows x 4 columns]

# %%
# First LEFT JOIN between stations and station_entrances on 'station_code'
merged_supabase_data_kv = pd.merge(stations_data_supa, station_entrances_data_supa, on='station_code', how='left')
merged_supabase_data_kv
# Out:
#                     name station_code  service_provider_name  latitude  \
# 0           Kuala Lumpur         KA02  Keretapi Tanah Melayu  3.139513
# 1            Bank Negara         KA03  Keretapi Tanah Melayu  3.154542
# 2                  Putra         KA04  Keretapi Tanah Melayu  3.165005
# 3             Mid Valley         KB01  Keretapi Tanah Melayu  3.118528
# 4                Seputeh         KB02  Keretapi Tanah Melayu  3.113697
# ..                   ...          ...                    ...       ...
# 444          Sri Andalas         JS22               Rapid KL  3.015225
# 445           Klang Jaya         JS23               Rapid KL  3.005072
# 446  Bandar Bukit Tinggi         JS24               Rapid KL  2.993526
# 447          Johan Setia         JS26               Rapid KL  2.975436
# 448           KL Sentral         KA01  Keretapi Tanah Melayu  3.134603
#
#       longitude route_id     route_name line_number line_colour  \
# 0    101.693789       KA  Seremban Line           1        Blue
# 1    101.693010       KA  Seremban Line           1        Blue
# 2    101.691234       KA  Seremban Line           1        Blue
# 3    101.678985       KB  Seremban Line           1        Blue
# 4    101.681299       KB  Seremban Line           1        Blue
# ..          ...      ...            ...         ...         ...
# 444  101.440441       JS           LRT3          11    Sky Blue
# 445  101.442081       JS           LRT3          11    Sky Blue
# 446  101.446175       JS           LRT3          11    Sky Blue
# 447  101.460718       JS           LRT3          11    Sky Blue
# 448  101.686567       KA  Seremban Line           1        Blue
#
#     colour_hex_code        region odonym namesake opened  entrance_id  \
# 0           #0000FF  Klang Valley   None     None   None          NaN
# 1           #0000FF  Klang Valley   None     None   None          NaN
# 2           #0000FF  Klang Valley   None     None   None          NaN
# 3           #0000FF  Klang Valley   None     None   None          NaN
# 4           #0000FF  Klang Valley   None     None   None          NaN
# ..              ...           ...    ...      ...    ...          ...
# 444         #88cffa  Klang Valley   None     None   None          NaN
# 445         #88cffa  Klang Valley   None     None   None          NaN
# 446         #88cffa  Klang Valley   None     None   None          NaN
# 447         #88cffa  Klang Valley   None     None   None          NaN
# 448         #0000FF  Klang Valley   None     None   None          NaN
#
#     station_name
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 444          NaN
# 445          NaN
# 446          NaN
# 447          NaN
# 448          NaN
#
# [449 rows x 16 columns]

# %%
# Second LEFT JOIN with entrances on 'entrance_id'
merged_supabase_data_kv = pd.merge(merged_supabase_data_kv, entrances_data_supa, on='entrance_id', how='left')
merged_supabase_data_kv
# Out:
#                     name station_code  service_provider_name  latitude  \
# 0           Kuala Lumpur         KA02  Keretapi Tanah Melayu  3.139513
# 1            Bank Negara         KA03  Keretapi Tanah Melayu  3.154542
# 2                  Putra         KA04  Keretapi Tanah Melayu  3.165005
# 3             Mid Valley         KB01  Keretapi Tanah Melayu  3.118528
# 4                Seputeh         KB02  Keretapi Tanah Melayu  3.113697
# ..                   ...          ...                    ...       ...
# 444          Sri Andalas         JS22               Rapid KL  3.015225
# 445           Klang Jaya         JS23               Rapid KL  3.005072
# 446  Bandar Bukit Tinggi         JS24               Rapid KL  2.993526
# 447          Johan Setia         JS26               Rapid KL  2.975436
# 448           KL Sentral         KA01  Keretapi Tanah Melayu  3.134603
#
#       longitude route_id     route_name line_number line_colour  \
# 0    101.693789       KA  Seremban Line           1        Blue
# 1    101.693010       KA  Seremban Line           1        Blue
# 2    101.691234       KA  Seremban Line           1        Blue
# 3    101.678985       KB  Seremban Line           1        Blue
# 4    101.681299       KB  Seremban Line           1        Blue
# ..          ...      ...            ...         ...         ...
# 444  101.440441       JS           LRT3          11    Sky Blue
# 445  101.442081       JS           LRT3          11    Sky Blue
# 446  101.446175       JS           LRT3          11    Sky Blue
# 447  101.460718       JS           LRT3          11    Sky Blue
# 448  101.686567       KA  Seremban Line           1        Blue
#
#     colour_hex_code        region odonym namesake opened  entrance_id  \
# 0           #0000FF  Klang Valley   None     None   None          NaN
# 1           #0000FF  Klang Valley   None     None   None          NaN
# 2           #0000FF  Klang Valley   None     None   None          NaN
# 3           #0000FF  Klang Valley   None     None   None          NaN
# 4           #0000FF  Klang Valley   None     None   None          NaN
# ..              ...           ...    ...      ...    ...          ...
# 444         #88cffa  Klang Valley   None     None   None          NaN
# 445         #88cffa  Klang Valley   None     None   None          NaN
# 446         #88cffa  Klang Valley   None     None   None          NaN
# 447         #88cffa  Klang Valley   None     None   None          NaN
# 448         #0000FF  Klang Valley   None     None   None          NaN
#
#     station_name  entrance_longitude  entrance_latitude entrance_destination  \
# 0            NaN                 NaN                NaN                  NaN
# 1            NaN                 NaN                NaN                  NaN
# 2            NaN                 NaN                NaN                  NaN
# 3            NaN                 NaN                NaN                  NaN
# 4            NaN                 NaN                NaN                  NaN
# ..           ...                 ...                ...                  ...
# 444          NaN                 NaN                NaN                  NaN
# 445          NaN                 NaN                NaN                  NaN
# 446          NaN                 NaN                NaN                  NaN
# 447          NaN                 NaN                NaN                  NaN
# 448          NaN                 NaN                NaN                  NaN
#
#     entrance_name
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 444           NaN
# 445           NaN
# 446           NaN
# 447           NaN
# 448           NaN
#
# [449 rows x 20 columns]

# %%
# Create a new column in your DataFrame for the geographic data
merged_supabase_data_kv['geometry'] = [Point(xy) for xy in zip(merged_supabase_data_kv.longitude, merged_supabase_data_kv.latitude)]

# Convert the DataFrame to a GeoDataFrame
merged_supabase_data_kv = gpd.GeoDataFrame(merged_supabase_data_kv, geometry='geometry')

# Set the coordinate reference system (CRS) to EPSG:4326 (WGS84)
merged_supabase_data_kv.crs = "EPSG:4326"

# %% [markdown]
# ### Visualize all Klang Valley Stations using Supabase

# %%
# Create a new DataFrame where each latitude and longitude pair is unique
unique_stations = merged_supabase_data_kv.drop_duplicates(subset=['latitude', 'longitude'])

# Create a map centered around the average latitude and longitude of the stations
map = folium.Map(location=[unique_stations['latitude'].mean(), unique_stations['longitude'].mean()], zoom_start=13)

# Add a marker for each station
for _, station in unique_stations.iterrows():
    folium.Marker(location=[station['latitude'], station['longitude']], 
                  popup=f"{station['name']} ({station['station_code']})").add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_daa56b7b639084f52c2a9df0366337f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_daa56b7b639084f52c2a9df0366337f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_daa56b7b639084f52c2a9df0366337f0 = L.map(
#                 &quot;map_daa56b7b639084f52c2a9df0366337f0&quot;,
#                 {
#                     center: [3.0966632591872343, 101.65890534765956],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6896a36c82240987c129f797a7499300 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_daa56b7b639084f52c2a9df0366337f0);
#
#
#             var marker_a993bb99082220b601f64fa1a50a8f96 = L.marker(
#                 [3.1395126, 101.6937889],
#                 {}
#             ).addTo(map_daa56b7b639084f52c2a9df0366337f0);
#
#
#         var popup_35183aac072a8924c4072762f7f20b28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1f2d461eeaccc5f91918ec852489f49 = $(`&lt;div id=&quot;html_c1f2d461eeaccc5f91918ec852489f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kuala Lumpur (KA02)&lt;/div&gt;`)[0];
#                 popup_35183aac072a8924c4072762f7f20b28.setContent(html_c1f2d461eeaccc5f91918ec852489f49);
#
#
#
#         marker_a993bb99082220b601f64fa1a50a8f96.bindPopup(popup_35183aac072a8924c4072762f7f20b28)
#         ;
#
#
#
#
#             var marker_05987bb88566e372a5f4add358f7fc5f = L.marker(
#                 [3.1545422, 101.6930105],
#                 {}
#             ).addTo(map_daa56b7b639084f52c2a9df0366337f0);
#
#
#         var popup_9ad7c82169efa88c0e763f78242699f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e415f90e9c0ac9c23e66128f0c3c1fe = $(`&lt;div id=&quot;html_5e415f90e9c0ac9c23e66128f0c3c1fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bank Negara (KA03)&lt;/div&gt;`)[0];
#                 popup_9ad7c82169efa88c0e763f78242699f1.setContent(html_5e415f90e9c0ac9c23e66128f0c3c1fe);
#
#
#
#         marker_05987bb88566e372a5f4add358f7fc5f.bindPopup(popup_9ad7c82169efa88c0e763f78242699f1)
#         ;
#
#
#
#
#             var marker_a1ce8517f1c9907a78e8d6d4e5ff5907 = L.marker(
#                 [3.165005, 101.691234],
#                 {}
#             ).addTo(map_daa56b7b639084f52c2a9df0366337f0);
#
#
#         var popup_b4b9361e20c5a31f6f5e70fbe1293aff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d5f182301dbb55794e84ae62241d43a = $(`&lt;div id=&quot;html_7d5f182301dbb55794e84ae62241d43a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Putra (KA04)&lt;/div&gt;`)[0];
#                 popup_b4b9361e20c5a31f6f5e70fbe1293aff.setContent(html_7d5f182301dbb55794e84ae62241d43a);
#
#
#
#         marker_a1ce8517f1c9907a78e8d6d4e5ff5907.bindPopup(popup_b4b9361e20c5a31f6f5e70fbe1293aff)
#         ;
#
#
#
#
#             var marker_ace8a9b3b81e8b4a9906b1b49b505c19 = L.marker(
#                 [3.1185282, 101.6789854],
#                 {}
#             ).addTo(map_daa56b7b639084f52c2a9df0366337f0);
#
#
#         var popup_402fcb162c2a64dcd0d6c3032079e7ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2fb4f3469b07d517e1ca7f6f3ddf5ecf = $(`&lt;div id=&quot;html_2fb4f3469b07d517e1ca7f6f3ddf5ecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mid Valley (KB01)&lt;/div&gt;`)[0];
#                 popup_402fcb162c2a64dcd0d6c3032079e7ef.setContent(html_2fb4f3469b07d517e1ca7f6f3ddf5ecf);
#
#
#
#         marker_ace8a9b3b81e8b4a9906b1b49b505c19.bindPopup(popup_402fcb162c2a64dcd0d6c3032079e7ef)
#         ;
#
#
#
#
#             var marker_d01dfeba35bc67fc922fc9a4d44255cf = L.marker(
#                 [3.1136966, 101.6812992],
#                 {}
#             ).addTo(map_daa56b7b639084f52c2a9df0366337f0);
#
#
#         var popup_169b42d2bc9b0c76533e17d6a52c1745 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3237375a5424996fe49387a2f28d8a90 = $(`&lt;div id=&quot;html_3237375a5424996fe49387a2f28d8a90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Seputeh (KB02)&lt;/div&gt;`)[0];
#                 popup_169b42d2bc9b0c76533e17d6a52c1745.setContent(html_3237375a5424996fe49387a2f28d8a90);
#
#
#
#         marker_d01dfeba35bc67fc922fc9a4d44255cf.bindPopup(popup_169b42d2bc9b0c76533e17d6a52c1745)
#         ;
#
#
#
#
#             var marker_b90b55b0caff9cc3b0dc4a3207576eb0 = L.marker(

# %% [markdown]
# ### Visualize all Klang Valley Station Entrances using Supabase

# %%
merged_supabase_data_kv
# Out:
#                     name station_code  service_provider_name  latitude  \
# 0           Kuala Lumpur         KA02  Keretapi Tanah Melayu  3.139513
# 1            Bank Negara         KA03  Keretapi Tanah Melayu  3.154542
# 2                  Putra         KA04  Keretapi Tanah Melayu  3.165005
# 3             Mid Valley         KB01  Keretapi Tanah Melayu  3.118528
# 4                Seputeh         KB02  Keretapi Tanah Melayu  3.113697
# ..                   ...          ...                    ...       ...
# 444          Sri Andalas         JS22               Rapid KL  3.015225
# 445           Klang Jaya         JS23               Rapid KL  3.005072
# 446  Bandar Bukit Tinggi         JS24               Rapid KL  2.993526
# 447          Johan Setia         JS26               Rapid KL  2.975436
# 448           KL Sentral         KA01  Keretapi Tanah Melayu  3.134603
#
#       longitude route_id     route_name line_number line_colour  \
# 0    101.693789       KA  Seremban Line           1        Blue
# 1    101.693010       KA  Seremban Line           1        Blue
# 2    101.691234       KA  Seremban Line           1        Blue
# 3    101.678985       KB  Seremban Line           1        Blue
# 4    101.681299       KB  Seremban Line           1        Blue
# ..          ...      ...            ...         ...         ...
# 444  101.440441       JS           LRT3          11    Sky Blue
# 445  101.442081       JS           LRT3          11    Sky Blue
# 446  101.446175       JS           LRT3          11    Sky Blue
# 447  101.460718       JS           LRT3          11    Sky Blue
# 448  101.686567       KA  Seremban Line           1        Blue
#
#     colour_hex_code  ... odonym namesake opened entrance_id  station_name  \
# 0           #0000FF  ...   None     None   None         NaN          None
# 1           #0000FF  ...   None     None   None         NaN          None
# 2           #0000FF  ...   None     None   None         NaN          None
# 3           #0000FF  ...   None     None   None         NaN          None
# 4           #0000FF  ...   None     None   None         NaN          None
# ..              ...  ...    ...      ...    ...         ...           ...
# 444         #88cffa  ...   None     None   None         NaN          None
# 445         #88cffa  ...   None     None   None         NaN          None
# 446         #88cffa  ...   None     None   None         NaN          None
# 447         #88cffa  ...   None     None   None         NaN          None
# 448         #0000FF  ...   None     None   None         NaN          None
#
#     entrance_longitude  entrance_latitude  entrance_destination entrance_name  \
# 0                  NaN                NaN                  None          None
# 1                  NaN                NaN                  None          None
# 2                  NaN                NaN                  None          None
# 3                  NaN                NaN                  None          None
# 4                  NaN                NaN                  None          None
# ..                 ...                ...                   ...           ...
# 444                NaN                NaN                  None          None
# 445                NaN                NaN                  None          None
# 446                NaN                NaN                  None          None
# 447                NaN                NaN                  None          None
# 448                NaN                NaN                  None          None
#
#                       geometry
# 0    POINT (101.69379 3.13951)
# 1    POINT (101.69301 3.15454)
# 2    POINT (101.69123 3.16500)
# 3    POINT (101.67899 3.11853)
# 4    POINT (101.68130 3.11370)
# ..                         ...
# 444  POINT (101.44044 3.01522)
# 445  POINT (101.44208 3.00507)
# 446  POINT (101.44617 2.99353)
# 447  POINT (101.46072 2.97544)
# 448  POINT (101.68657 3.13460)
#
# [449 rows x 21 columns]

# %%
# Create a new DataFrame where each entrances latitude and longitude pair is available
valid_entrances = merged_supabase_data_kv.dropna(subset=['entrance_latitude', 'entrance_longitude'])

# Create a map centered around the average latitude and longitude of the stations
map = folium.Map(location=[valid_entrances['entrance_latitude'].mean(), valid_entrances['entrance_longitude'].mean()], zoom_start=13)

# Add a marker for each station
for _, entrance in valid_entrances.iterrows():
    folium.Marker(location=[entrance['entrance_latitude'], entrance['entrance_longitude']], 
                  popup=f"{entrance['name']} ({entrance['station_code']})",
                  icon=folium.Icon(color="red", icon="")
                  ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a0764bacd89ef7b9a73f13e0102278c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a0764bacd89ef7b9a73f13e0102278c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a0764bacd89ef7b9a73f13e0102278c = L.map(
#                 &quot;map_0a0764bacd89ef7b9a73f13e0102278c&quot;,
#                 {
#                     center: [3.1149235392617447, 101.68878303087249],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b86d9499443a6565a61e0e52714a8403 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a0764bacd89ef7b9a73f13e0102278c);
#
#
#             var marker_d88c24b46719d23c87df2a30f4c830e4 = L.marker(
#                 [2.9838212, 101.79089],
#                 {}
#             ).addTo(map_0a0764bacd89ef7b9a73f13e0102278c);
#
#
#             var icon_f9726839a678d75693f32ee59356c1e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d88c24b46719d23c87df2a30f4c830e4.setIcon(icon_f9726839a678d75693f32ee59356c1e2);
#
#
#         var popup_664f7c1e28bcb9036de773566d819c7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3965149b264fac4bb27f71ef1f37ee34 = $(`&lt;div id=&quot;html_3965149b264fac4bb27f71ef1f37ee34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kajang (KB06)&lt;/div&gt;`)[0];
#                 popup_664f7c1e28bcb9036de773566d819c7e.setContent(html_3965149b264fac4bb27f71ef1f37ee34);
#
#
#
#         marker_d88c24b46719d23c87df2a30f4c830e4.bindPopup(popup_664f7c1e28bcb9036de773566d819c7e)
#         ;
#
#
#
#
#             var marker_05b9daed90e23f605e9050b96b50d51a = L.marker(
#                 [2.9829814, 101.7900849],
#                 {}
#             ).addTo(map_0a0764bacd89ef7b9a73f13e0102278c);
#
#
#             var icon_268f9668c182c3176281725c13bfb6ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_05b9daed90e23f605e9050b96b50d51a.setIcon(icon_268f9668c182c3176281725c13bfb6ff);
#
#
#         var popup_9a562cc4a0d29eeb2ac6e85a58a72631 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d732c800a76fba0d0fe0814af1edb322 = $(`&lt;div id=&quot;html_d732c800a76fba0d0fe0814af1edb322&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kajang (KB06)&lt;/div&gt;`)[0];
#                 popup_9a562cc4a0d29eeb2ac6e85a58a72631.setContent(html_d732c800a76fba0d0fe0814af1edb322);
#
#
#
#         marker_05b9daed90e23f605e9050b96b50d51a.bindPopup(popup_9a562cc4a0d29eeb2ac6e85a58a72631)
#         ;
#
#
#
#
#             var marker_97826722a788ddcac5bffcef6dca2fd9 = L.marker(
#                 [3.1854636, 101.695385],
#                 {}
#             ).addTo(map_0a0764bacd89ef7b9a73f13e0102278c);
#
#
#             var icon_16fdac728dc0cad88e100da1ed78a26d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97826722a788ddcac5bffcef6dca2fd9.setIcon(icon_16fdac728dc0cad88e100da1ed78a26d);
#
#
#         var popup_43b7b5ddacae78322f4f64ac25582574 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb765857082063fc9cb7363761d6678f = $(`&lt;div id=&quot;html_cb765857082063fc9cb7363761d6678f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sentul Timur (AG1)&lt;/div&gt;`)[0];
#                 popup_43b7b5ddacae78322f4f64ac25582574.setContent(html_cb765857082063fc9cb7363761d6678f);
#
#
#
#         marker_97826722a788ddcac5bffcef6dca2fd9.bindPopup(popup_43b7b5ddacae78322f4f64ac25582574)
#         ;
#
#
#
#
#             var marker_0fb3ae9acaeab03142f4ca01a0c5037a = L.marker(
#                 [3.1347568, 101.7121408],
#                 {}
#             ).addTo(map_0a0764bacd89ef7b9a73f13e0102278c);
#
#
#             var icon_6d29e99813242902bd112b64601da1be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quo
