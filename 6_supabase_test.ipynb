# %% [markdown]
# # Testing Out Supabase Client

# %%
import os
import pandas as pd
from supabase import create_client, Client

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
response = supabase.table('stations').select("*").execute()
data,_ = response
data[1]
df = pd.DataFrame(data[1])
df
# Out:
#                                                   name station_code  \
# 0                                         Kuala Lumpur         KA02
# 1                                          Bank Negara         KA03
# 2                                                Putra         KA04
# 3                                           Mid Valley         KB01
# 4                                              Seputeh         KB02
# ..                                                 ...          ...
# 531                                Maxwell MRT Station         TE18
# 532                            Shenton Way MRT Station         TE19
# 533                             Marina Bay MRT Station         TE20
# 534  Gardens By The Bay • Taman Di Pesisiran MRT St...         TE22
# 535                                         KL Sentral         KA01
#
#      service_provider_name  latitude   longitude route_id  \
# 0    Keretapi Tanah Melayu  3.139513  101.693789       KA
# 1    Keretapi Tanah Melayu  3.154542  101.693010       KA
# 2    Keretapi Tanah Melayu  3.165005  101.691234       KA
# 3    Keretapi Tanah Melayu  3.118528  101.678985       KB
# 4    Keretapi Tanah Melayu  3.113697  101.681299       KB
# ..                     ...       ...         ...      ...
# 531                   None  1.280600  103.844000      TEL
# 532                   None  1.277540  103.850770      TEL
# 533                   None  1.275290  103.854810      TEL
# 534                   None  1.279000  103.867800      TEL
# 535  Keretapi Tanah Melayu  3.134603  101.686567       KA
#
#                   route_name line_number line_colour colour_hex_code  \
# 0              Seremban Line           1        Blue         #0000FF
# 1              Seremban Line           1        Blue         #0000FF
# 2              Seremban Line           1        Blue         #0000FF
# 3              Seremban Line           1        Blue         #0000FF
# 4              Seremban Line           1        Blue         #0000FF
# ..                       ...         ...         ...             ...
# 531  Thomson-East Coast Line        None       Brown         #734538
# 532  Thomson-East Coast Line        None       Brown         #734538
# 533  Thomson-East Coast Line        None       Brown         #734538
# 534  Thomson-East Coast Line        None       Brown         #734538
# 535            Seremban Line           1        Blue         #0000FF
#
#            region odonym namesake opened  station_id
# 0    Klang Valley   None     None   None           1
# 1    Klang Valley   None     None   None           2
# 2    Klang Valley   None     None   None           3
# 3    Klang Valley   None     None   None           4
# 4    Klang Valley   None     None   None           5
# ..            ...    ...      ...    ...         ...
# 531     Singapore   None     None   None         532
# 532     Singapore   None     None   None         533
# 533     Singapore   None     None   None         534
# 534     Singapore   None     None   None         535
# 535  Klang Valley   None     None   None           0
#
# [536 rows x 15 columns]

# %%
response = supabase.table('entrances').select("*").execute()
data,_ = response
data[1]
df = pd.DataFrame(data[1])
df
# Out:
#      entrance_id   longitude  latitude  \
# 0     3308608988  101.712717  3.158762
# 1     3308608989  101.712507  3.158809
# 2     4092013971  101.614130  3.022231
# 3     4400847336  101.698939  3.139210
# 4     4952299503  101.732720  3.104671
# ..           ...         ...       ...
# 258   5261535528  101.578793  3.196710
# 259   5484616509  101.593617  3.149892
# 260  10277840675  101.745860  3.077479
# 261  11768032038  101.693320  3.154872
# 262  11768421750  101.693051  3.154850
#
#                                   entrance_destination entrance_name
# 0                                                 None          None
# 1                                                 None          None
# 2                                                 None          None
# 3                                                 None             A
# 4                                                 None             B
# ..                                                 ...           ...
# 258                                 Jalan Sungai Buloh             B
# 259  Jalan PJU 5/8;Sunway Giza;Dataran Sunway;Encor...             B
# 260                                               None             C
# 261                                               None          None
# 262                                               None          None
#
# [263 rows x 5 columns]

# %%
response = supabase.table('station_entrances').select("*").execute()
data,_ = response
data[1]
df = pd.DataFrame(data[1])
df
# Out:
#      relationship_id  entrance_id             station_name station_code
# 0                  0  10796851698                     Pudu         AG10
# 1                  1  10796851698                     Pudu         SP10
# 2                  2   5485710279             Kampung Baru         KJ11
# 3                  3   5485710278             Kampung Baru         KJ11
# 4                  4   9740843587        Masjid Jamek (KJ)         KJ13
# ..               ...          ...                      ...          ...
# 294              294  10722980582  Putrajaya Sentral (MRT)         PY41
# 295              295   5044809585  Tun Razak Exchange (PY)         PY23
# 296              296   5044809586  Tun Razak Exchange (PY)         PY23
# 297              297   5044809585  Tun Razak Exchange (PY)         PY23
# 298              298   5044809586  Tun Razak Exchange (PY)         PY23
#
# [299 rows x 4 columns]
