# %% [markdown]
# # Testing Out Supabase Client

# %%
import os
import pandas as pd
from supabase import create_client, Client

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
response = supabase.table('entrances').select("*").execute()

# %%
data,_ = response

# %%
type(data)
# Out:
# tuple

# %%
data[1]
# Out:
# [{'entrance_id': 1544031348,
#   'longitude': 101.7113737,
#   'latitude': 3.1459286,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 1631412559,
#   'longitude': 101.6049519,
#   'latitude': 3.1132222,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 2278515570,
#   'longitude': 101.644077,
#   'latitude': 3.0506498,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 2686635178,
#   'longitude': 101.6991821,
#   'latitude': 3.1385646,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 3308608988,
#   'longitude': 101.7127175,
#   'latitude': 3.1587619,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 3308608989,
#   'longitude': 101.7125072,
#   'latitude': 3.1588091,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 4092013971,
#   'longitude': 101.6141298,
#   'latitude': 3.0222312,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 4400847336,
#   'longitude': 101.6989388,
#   'latitude': 3.1392105,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 4533242217,
#   'longitude': 101.578194,
#   'latitude': 3.199222,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 4952299496,
#   'longitude': 101.7290571,
#   'latitude': 3.1117149,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 4952299503,
#   'longitude': 101.7327199,
#   'latitude': 3.1046709,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5040821684,
#   'longitude': 101.7117293,
#   'latitude': 3.146919,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 5040821685,
#   'longitude': 101.7116779,
#   'latitude': 3.1471083,
#   'entrance_destination': None,
#   'entrance_name': 'E'},
#  {'entrance_id': 5040821686,
#   'longitude': 101.7110722,
#   'latitude': 3.1469708,
#   'entrance_destination': None,
#   'entrance_name': 'F'},
#  {'entrance_id': 5040821688,
#   'longitude': 101.7099729,
#   'latitude': 3.1461865,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5040821689,
#   'longitude': 101.7105645,
#   'latitude': 3.1459943,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5042521354,
#   'longitude': 101.7269761,
#   'latitude': 3.1253842,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5042521355,
#   'longitude': 101.7277502,
#   'latitude': 3.1242309,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 5042521364,
#   'longitude': 101.7273764,
#   'latitude': 3.1238629,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5042521365,
#   'longitude': 101.7269783,
#   'latitude': 3.1245224,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5043240641,
#   'longitude': 101.702138,
#   'latitude': 3.142434,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5043240648,
#   'longitude': 101.7027996,
#   'latitude': 3.1416851,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5044809566,
#   'longitude': 101.6955575,
#   'latitude': 3.1421773,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5044809567,
#   'longitude': 101.6968069,
#   'latitude': 3.1424829,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5044809568,
#   'longitude': 101.6876932,
#   'latitude': 3.1373932,
#   'entrance_destination': 'Muzium Negara',
#   'entrance_name': 'B'},
#  {'entrance_id': 5044809569,
#   'longitude': 101.6877598,
#   'latitude': 3.1369827,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5044809580,
#   'longitude': 101.7229314,
#   'latitude': 3.1329233,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5044809584,
#   'longitude': 101.723198,
#   'latitude': 3.1320204,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5044809585,
#   'longitude': 101.7198454,
#   'latitude': 3.1429773,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5044809586,
#   'longitude': 101.7200141,
#   'latitude': 3.1425578,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5261439396,
#   'longitude': 101.5647253,
#   'latitude': 3.1701365,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5261535528,
#   'longitude': 101.5787927,
#   'latitude': 3.1967103,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5261535531,
#   'longitude': 101.5776747,
#   'latitude': 3.198102,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5261535537,
#   'longitude': 101.5651486,
#   'latitude': 3.1698737,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5261535560,
#   'longitude': 101.607848,
#   'latitude': 3.1559391,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5261535561,
#   'longitude': 101.6082016,
#   'latitude': 3.1559331,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5261535570,
#   'longitude': 101.6091179,
#   'latitude': 3.1548978,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5261535576,
#   'longitude': 101.6091314,
#   'latitude': 3.1555885,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 5261535590,
#   'longitude': 101.6188927,
#   'latitude': 3.1457012,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5383383307,
#   'longitude': 101.6455336,
#   'latitude': 3.1037967,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5385396790,
#   'longitude': 101.6656456,
#   'latitude': 3.1506493,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5385396799,
#   'longitude': 101.6657104,
#   'latitude': 3.151504,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5386930796,
#   'longitude': 101.6954278,
#   'latitude': 3.1725154,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5392028001,
#   'longitude': 101.7191447,
#   'latitude': 3.15986,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5469085305,
#   'longitude': 101.7745994,
#   'latitude': 3.0483351,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085306,
#   'longitude': 101.7742876,
#   'latitude': 3.0483404,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5469085434,
#   'longitude': 101.7407913,
#   'latitude': 3.0911621,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5469085436,
#   'longitude': 101.7402187,
#   'latitude': 3.0906021,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085437,
#   'longitude': 101.7406003,
#   'latitude': 3.0914705,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5469085483,
#   'longitude': 101.7730056,
#   'latitude': 3.0623535,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085491,
#   'longitude': 101.7727877,
#   'latitude': 3.06117,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5469085492,
#   'longitude': 101.7735523,
#   'latitude': 3.0616414,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5469085624,
#   'longitude': 101.7709892,
#   'latitude': 3.0272459,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085625,
#   'longitude': 101.7720253,
#   'latitude': 3.0273688,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5469085628,
#   'longitude': 101.783749,
#   'latitude': 3.0004592,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085629,
#   'longitude': 101.7837971,
#   'latitude': 3.0013333,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5469085630,
#   'longitude': 101.7859006,
#   'latitude': 2.9928751,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5469085631,
#   'longitude': 101.7861107,
#   'latitude': 2.9944474,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085632,
#   'longitude': 101.7862931,
#   'latitude': 2.9934309,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5469085633,
#   'longitude': 101.7637348,
#   'latitude': 3.0716741,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085640,
#   'longitude': 101.7460092,
#   'latitude': 3.0785733,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085641,
#   'longitude': 101.7450245,
#   'latitude': 3.079458,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5469085643,
#   'longitude': 101.7453938,
#   'latitude': 3.0784729,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5469085650,
#   'longitude': 101.7296842,
#   'latitude': 3.1118305,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5469085653,
#   'longitude': 101.7731055,
#   'latitude': 3.0413224,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5484250431,
#   'longitude': 101.6625513,
#   'latitude': 3.1435532,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5484250432,
#   'longitude': 101.6631665,
#   'latitude': 3.1434524,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5484250466,
#   'longitude': 101.6429952,
#   'latitude': 3.1295348,
#   'entrance_destination': 'Lebuhraya SPRINT',
#   'entrance_name': 'B'},
#  {'entrance_id': 5484250467,
#   'longitude': 101.6427664,
#   'latitude': 3.1283532,
#   'entrance_destination': 'Jalan 16/11',
#   'entrance_name': 'A'},
#  {'entrance_id': 5484250474,
#   'longitude': 101.6312433,
#   'latitude': 3.1360369,
#   'entrance_destination': 'Jalan Wan Kadir 4',
#   'entrance_name': 'B'},
#  {'entrance_id': 5484250475,
#   'longitude': 101.6302937,
#   'latitude': 3.1356637,
#   'entrance_destination': 'Menara Glomac',
#   'entrance_name': 'A'},
#  {'entrance_id': 5484616509,
#   'longitude': 101.5936166,
#   'latitude': 3.1498921,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5484616510,
#   'longitude': 101.5935975,
#   'latitude': 3.1494285,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5484616643,
#   'longitude': 101.5793786,
#   'latitude': 3.1504398,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5484616646,
#   'longitude': 101.5786349,
#   'latitude': 3.1499793,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 5485710268,
#   'longitude': 101.7184343,
#   'latitude': 3.1603959,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5485710278,
#   'longitude': 101.7066125,
#   'latitude': 3.1612899,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5485710279,
#   'longitude': 101.7072844,
#   'latitude': 3.1615617,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5486069126,
#   'longitude': 101.5901459,
#   'latitude': 3.0954324,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 5488029391,
#   'longitude': 101.6183414,
#   'latitude': 3.1471418,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5581685893,
#   'longitude': 101.7117341,
#   'latitude': 3.1460892,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 5624757756,
#   'longitude': 101.6956284,
#   'latitude': 3.1733467,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5624757758,
#   'longitude': 101.6958171,
#   'latitude': 3.1729825,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5641420313,
#   'longitude': 101.6985721,
#   'latitude': 3.1591411,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 5724964836,
#   'longitude': 101.6985435,
#   'latitude': 3.1594271,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5726983880,
#   'longitude': 101.745813,
#   'latitude': 3.0773976,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5858640711,
#   'longitude': 101.7116087,
#   'latitude': 3.1462184,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 5858640712,
#   'longitude': 101.711317,
#   'latitude': 3.1461311,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 6162833429,
#   'longitude': 101.5820341,
#   'latitude': 3.0296234,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 6162845303,
#   'longitude': 101.581271,
#   'latitude': 3.0295794,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 6375602764,
#   'longitude': 101.7116602,
#   'latitude': 3.1460223,
#   'entrance_destination': None,
#   'entrance_name': 'E'},
#  {'entrance_id': 6575190638,
#   'longitude': 101.7080119,
#   'latitude': 3.0634977,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 6782815005,
#   'longitude': 101.7057869,
#   'latitude': 3.1406982,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 6782815006,
#   'longitude': 101.7061612,
#   'latitude': 3.1410094,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 7042863007,
#   'longitude': 101.7061185,
#   'latitude': 3.140592,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 7056476413,
#   'longitude': 101.6447464,
#   'latitude': 3.0509896,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 7056476416,
#   'longitude': 101.6451619,
#   'latitude': 3.050308,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 7056476417,
#   'longitude': 101.644375,
#   'latitude': 3.0502361,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 7056476419,
#   'longitude': 101.6449537,
#   'latitude': 3.0504795,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 7104299331,
#   'longitude': 101.7273717,
#   'latitude': 3.1251558,
#   'entrance_destination': None,
#   'entrance_name': 'AEON'},
#  {'entrance_id': 7150491826,
#   'longitude': 101.5862977,
#   'latitude': 3.0765187,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 7150491837,
#   'longitude': 101.5859436,
#   'latitude': 3.0756213,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 7259253706,
#   'longitude': 101.6991072,
#   'latitude': 3.1590919,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 7299533782,
#   'longitude': 101.7319006,
#   'latitude': 3.1049728,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 7308309728,
#   'longitude': 101.7726712,
#   'latitude': 3.0406991,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 7387995582,
#   'longitude': 101.7097169,
#   'latitude': 3.1430868,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 7387995584,
#   'longitude': 101.7098758,
#   'latitude': 3.142727,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 7702628710,
#   'longitude': 101.79089,
#   'latitude': 2.9838212,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 7733651045,
#   'longitude': 101.6125364,
#   'latitude': 3.0162107,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 7733651046,
#   'longitude': 101.6128542,
#   'latitude': 3.0160515,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 8074913901,
#   'longitude': 101.5907454,
#   'latitude': 3.0961458,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 8711020731,
#   'longitude': 101.5859412,
#   'latitude': 3.0670668,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9221724469,
#   'longitude': 101.6558631,
#   'latitude': 3.2097348,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9221724470,
#   'longitude': 101.6559017,
#   'latitude': 3.2093868,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9221724471,
#   'longitude': 101.648012,
#   'latitude': 3.2107181,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9221724474,
#   'longitude': 101.6083453,
#   'latitude': 3.1978429,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9221724475,
#   'longitude': 101.6080406,
#   'latitude': 3.1985341,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9221724476,
#   'longitude': 101.5924942,
#   'latitude': 3.2000956,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9229552290,
#   'longitude': 101.6208466,
#   'latitude': 3.1986159,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9229552291,
#   'longitude': 101.6208793,
#   'latitude': 3.1983477,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9229566390,
#   'longitude': 101.5925125,
#   'latitude': 3.1997354,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9358657242,
#   'longitude': 101.5948556,
#   'latitude': 3.1500335,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9361137458,
#   'longitude': 101.612643,
#   'latitude': 3.1108192,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9378300196,
#   'longitude': 101.6792866,
#   'latitude': 3.1939803,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9378325928,
#   'longitude': 101.6797648,
#   'latitude': 3.1964629,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9439800347,
#   'longitude': 101.7065497,
#   'latitude': 3.1406353,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 9504210024,
#   'longitude': 101.6909066,
#   'latitude': 3.1315206,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9504210028,
#   'longitude': 101.6878032,
#   'latitude': 3.1328157,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9508388055,
#   'longitude': 101.7094062,
#   'latitude': 3.1426296,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 9508388057,
#   'longitude': 101.7095249,
#   'latitude': 3.1425262,
#   'entrance_destination': None,
#   'entrance_name': 'E'},
#  {'entrance_id': 9508388060,
#   'longitude': 101.7094003,
#   'latitude': 3.1430137,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9508388065,
#   'longitude': 101.7102446,
#   'latitude': 3.1509066,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9508388066,
#   'longitude': 101.7105244,
#   'latitude': 3.1508352,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9508388067,
#   'longitude': 101.7101502,
#   'latitude': 3.1506686,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9508388068,
#   'longitude': 101.7045396,
#   'latitude': 3.1562731,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9508388069,
#   'longitude': 101.7049268,
#   'latitude': 3.1563885,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9508388070,
#   'longitude': 101.7050705,
#   'latitude': 3.155998,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9508388071,
#   'longitude': 101.6991144,
#   'latitude': 3.1593744,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 9508388072,
#   'longitude': 101.6982849,
#   'latitude': 3.1669355,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9508388077,
#   'longitude': 101.6989708,
#   'latitude': 3.1675364,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9508388079,
#   'longitude': 101.6960765,
#   'latitude': 3.1730738,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9646411432,
#   'longitude': 101.7087611,
#   'latitude': 3.0636527,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9740843587,
#   'longitude': 101.6966656,
#   'latitude': 3.1495984,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9774145253,
#   'longitude': 101.6755411,
#   'latitude': 3.2051788,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9849423415,
#   'longitude': 101.5804609,
#   'latitude': 3.2064203,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9849457821,
#   'longitude': 101.5809062,
#   'latitude': 3.2057282,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9849592637,
#   'longitude': 101.5923368,
#   'latitude': 3.2000096,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9849815460,
#   'longitude': 101.6396741,
#   'latitude': 3.2140816,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9849815463,
#   'longitude': 101.655764,
#   'latitude': 3.208606,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9849815470,
#   'longitude': 101.666194,
#   'latitude': 3.2067994,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9849815474,
#   'longitude': 101.666548,
#   'latitude': 3.2054264,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9850359889,
#   'longitude': 101.628585,
#   'latitude': 3.2079071,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9850375320,
#   'longitude': 101.6399277,
#   'latitude': 3.2144708,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9850375370,
#   'longitude': 101.6489325,
#   'latitude': 3.2113028,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9850375371,
#   'longitude': 101.6487012,
#   'latitude': 3.2112522,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9853266686,
#   'longitude': 101.5723031,
#   'latitude': 3.1766755,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9900002870,
#   'longitude': 101.7178503,
#   'latitude': 3.1616711,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9909030875,
#   'longitude': 101.6045094,
#   'latitude': 3.1127417,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9913020228,
#   'longitude': 101.6844092,
#   'latitude': 3.1795286,
#   'entrance_destination': 'Jalan Sultan Azlan Shah (Kuala Lumpur)',
#   'entrance_name': 'C'},
#  {'entrance_id': 9913020229,
#   'longitude': 101.6851874,
#   'latitude': 3.1785215,
#   'entrance_destination': 'Jalan Sultan Azlan Shah (Kepong)',
#   'entrance_name': 'B'},
#  {'entrance_id': 9913020238,
#   'longitude': 101.681422,
#   'latitude': 3.1895909,
#   'entrance_destination': 'Jalan Sultan Azlan Shah',
#   'entrance_name': 'B'},
#  {'entrance_id': 9913027336,
#   'longitude': 101.695378,
#   'latitude': 3.1856051,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9914411088,
#   'longitude': 101.7072341,
#   'latitude': 3.0285907,
#   'entrance_destination': 'Jalan Utama',
#   'entrance_name': 'A'},
#  {'entrance_id': 9914411090,
#   'longitude': 101.7047478,
#   'latitude': 3.0416764,
#   'entrance_destination': 'Jalan Utama',
#   'entrance_name': 'A'},
#  {'entrance_id': 9919591009,
#   'longitude': 101.6658468,
#   'latitude': 3.207186,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9924537172,
#   'longitude': 101.613442,
#   'latitude': 3.0227412,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 9924537173,
#   'longitude': 101.6871067,
#   'latitude': 3.0611094,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9924537197,
#   'longitude': 101.715929,
#   'latitude': 3.1288205,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9933445412,
#   'longitude': 101.7361181,
#   'latitude': 3.1760297,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 9933445415,
#   'longitude': 101.7357293,
#   'latitude': 3.1758808,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 9933445416,
#   'longitude': 101.735265,
#   'latitude': 3.1756716,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9983121349,
#   'longitude': 101.6989191,
#   'latitude': 3.1594579,
#   'entrance_destination': None,
#   'entrance_name': 'E'},
#  {'entrance_id': 9983121350,
#   'longitude': 101.6965409,
#   'latitude': 3.1491501,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 9983207462,
#   'longitude': 101.6231592,
#   'latitude': 3.1048242,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 10211729864,
#   'longitude': 101.7057771,
#   'latitude': 3.0431699,
#   'entrance_destination': 'Jalan OS (One South City)',
#   'entrance_name': 'B'},
#  {'entrance_id': 10211729868,
#   'longitude': 101.7077539,
#   'latitude': 3.0295622,
#   'entrance_destination': 'Jalan SP 2/4 (Taman Serdang Perdana)',
#   'entrance_name': 'B'},
#  {'entrance_id': 10216200615,
#   'longitude': 101.7183643,
#   'latitude': 3.1574126,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 10223843931,
#   'longitude': 101.7900849,
#   'latitude': 2.9829814,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10266244039,
#   'longitude': 101.660675,
#   'latitude': 2.9835803,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 10270864772,
#   'longitude': 101.6958928,
#   'latitude': 3.1737287,
#   'entrance_destination': 'Jalan Pahang Barat',
#   'entrance_name': 'A'},
#  {'entrance_id': 10270868702,
#   'longitude': 101.6972538,
#   'latitude': 3.1741978,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 10270868726,
#   'longitude': 101.7006824,
#   'latitude': 3.1730906,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10270868727,
#   'longitude': 101.7023686,
#   'latitude': 3.1740579,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 10270868745,
#   'longitude': 101.7124702,
#   'latitude': 3.167741,
#   'entrance_destination': 'Jalan Tun Razak',
#   'entrance_name': 'D'},
#  {'entrance_id': 10271036579,
#   'longitude': 101.7099059,
#   'latitude': 3.1677008,
#   'entrance_destination': 'Jalan Raja Muda Abdul Aziz',
#   'entrance_name': 'A'},
#  {'entrance_id': 10271036580,
#   'longitude': 101.7097873,
#   'latitude': 3.1681411,
#   'entrance_destination': 'Jalan Raja Muda Abdul Aziz',
#   'entrance_name': 'B'},
#  {'entrance_id': 10271036605,
#   'longitude': 101.7181542,
#   'latitude': 3.1625464,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10271036965,
#   'longitude': 101.714978,
#   'latitude': 3.1269192,
#   'entrance_destination': 'Jalan Metro Pudu',
#   'entrance_name': 'C'},
#  {'entrance_id': 10271036984,
#   'longitude': 101.7165731,
#   'latitude': 3.1285816,
#   'entrance_destination': 'Jalan Chan Sow Lin',
#   'entrance_name': 'A'},
#  {'entrance_id': 10271039830,
#   'longitude': 101.7181983,
#   'latitude': 3.150151,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 10271039842,
#   'longitude': 101.7184289,
#   'latitude': 3.1517688,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10271071855,
#   'longitude': 101.7161066,
#   'latitude': 3.1275982,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 10594184537,
#   'longitude': 101.7090959,
#   'latitude': 3.0213387,
#   'entrance_destination': 'Jalan Raya Satu (Balai Bomba Serdang)',
#   'entrance_name': 'A'},
#  {'entrance_id': 10594184538,
#   'longitude': 101.7087929,
#   'latitude': 3.0214876,
#   'entrance_destination': 'Jalan Raya Satu (Taman Kembang Sari)',
#   'entrance_name': 'B'},
#  {'entrance_id': 10611678880,
#   'longitude': 101.706199,
#   'latitude': 3.0086059,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10611678881,
#   'longitude': 101.661231,
#   'latitude': 2.9833139,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10611678882,
#   'longitude': 101.6545593,
#   'latitude': 2.9650184,
#   'entrance_destination': 'Persiaran Sierra Utama',
#   'entrance_name': 'B'},
#  {'entrance_id': 10658294223,
#   'longitude': 101.6653737,
#   'latitude': 2.9395168,
#   'entrance_destination': 'Off Persiaran APEC',
#   'entrance_name': 'A'},
#  {'entrance_id': 10660535048,
#   'longitude': 101.6806186,
#   'latitude': 3.1897855,
#   'entrance_destination': 'Jalan Sultan Azlan Shah (Kompleks Mutiara)',
#   'entrance_name': 'A'},
#  {'entrance_id': 10706850272,
#   'longitude': 101.6724086,
#   'latitude': 2.9898661,
#   'entrance_destination': 'Jalan Putra Permai',
#   'entrance_name': 'B'},
#  {'entrance_id': 10722980582,
#   'longitude': 101.6717395,
#   'latitude': 2.9317531,
#   'entrance_destination': None,
#   'entrance_name': 'B'},
#  {'entrance_id': 10723194529,
#   'longitude': 101.6727608,
#   'latitude': 2.9891003,
#   'entrance_destination': 'Jalan PP 40',
#   'entrance_name': 'A'},
#  {'entrance_id': 10727740945,
#   'longitude': 101.6996604,
#   'latitude': 3.0771713,
#   'entrance_destination': 'Off Jalan 4/140',
#   'entrance_name': 'A'},
#  {'entrance_id': 10727805627,
#   'longitude': 101.6801389,
#   'latitude': 3.1905574,
#   'entrance_destination': 'Jalan Sultan Azlan Shah (Ke Arah Kepong)',
#   'entrance_name': 'C'},
#  {'entrance_id': 10795590948,
#   'longitude': 101.6938877,
#   'latitude': 3.0896471,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10795657618,
#   'longitude': 101.6454638,
#   'latitude': 3.1038599,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 10796851698,
#   'longitude': 101.7121408,
#   'latitude': 3.1347568,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 10800273158,
#   'longitude': 101.6955989,
#   'latitude': 3.1425051,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 10804709653,
#   'longitude': 101.6620724,
#   'latitude': 3.1146593,
#   'entrance_destination': None,
#   'entrance_name': 'A'},
#  {'entrance_id': 10804709680,
#   'longitude': 101.662096,
#   'latitude': 3.1145737,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 10830050822,
#   'longitude': 101.6877622,
#   'latitude': 3.1328275,
#   'entrance_destination': None,
#   'entrance_name': 'C'},
#  {'entrance_id': 10839997852,
#   'longitude': 101.657207,
#   'latitude': 2.9497119,
#   'entrance_destination': 'Off Persiaran APEC',
#   'entrance_name': 'A'},
#  {'entrance_id': 10860751179,
#   'longitude': 101.6952256,
#   'latitude': 3.1732229,
#   'entrance_destination': None,
#   'entrance_name': 'D'},
#  {'entrance_id': 10864116957,
#   'longitude': 101.7314751,
#   'latitude': 3.1651901,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 10949038882,
#   'longitude': 101.6808258,
#   'latitude': 3.2376063,
#   'entrance_destination': None,
#   'entrance_name': None},
#  {'entrance_id': 10949038884,
#   'longitude': 101.6814387,
#   'latitude': 3.237779,
#   'entrance_destination': None,
#   'entrance_name': None}]

# %%
df = pd.DataFrame(data[1])

# %%
df
# Out:
#      entrance_id   longitude  latitude entrance_destination entrance_name
# 0     1544031348  101.711374  3.145929                 None             B
# 1     1631412559  101.604952  3.113222                 None          None
# 2     2278515570  101.644077  3.050650                 None          None
# 3     2686635178  101.699182  3.138565                 None             C
# 4     3308608988  101.712717  3.158762                 None          None
# ..           ...         ...       ...                  ...           ...
# 211  10839997852  101.657207  2.949712   Off Persiaran APEC             A
# 212  10860751179  101.695226  3.173223                 None             D
# 213  10864116957  101.731475  3.165190                 None          None
# 214  10949038882  101.680826  3.237606                 None          None
# 215  10949038884  101.681439  3.237779                 None          None
#
# [216 rows x 5 columns]
